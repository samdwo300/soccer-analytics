# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load your merged stats/salary file (update path as needed)
df = pd.read_csv("seriea_2024_2025_stats/player_team_salary_stats_2024-2025_SerieA.csv")

# %%
df.head()
# Out:
#    Rk            Player   Nation    Pos    Squad  Age  Born  Playing Time_MP  \
# 0   5     tammy abraham  eng ENG     FW    milan   26  1997               28
# 1   8         che adams  sct SCO     FW   torino   28  1996               36
# 2  18   pontus almqvist   se SWE  FW,MF    parma   25  1999               29
# 3  26       arthur atta   fr FRA  MF,FW  udinese   21  2003               27
# 4  36  tommaso baldanzi   it ITA  MF,FW     roma   21  2003               31
#
#    Playing Time_Starts  Playing Time_Min  ...  Shots  SoT  Goals_per90  \
# 0                   12              1183  ...     26   11     0.228233
# 1                   30              2652  ...     63   25     0.305430
# 2                   10              1112  ...     26    9     0.080935
# 3                   12              1251  ...     26    7     0.000000
# 4                    5               832  ...     20    4     0.108173
#
#    Shot_Conversion   SoT_pct   xG  xG_per_shot  G_minus_xG  Salary_M_USD  \
# 0         0.115385  0.423077  7.1     0.273077        -4.1      5.947890
# 1         0.142857  0.396825  9.0     0.142857         0.0      3.432664
# 2         0.038462  0.346154  2.1     0.080769        -1.1      1.144221
# 3         0.000000  0.269231  1.3     0.050000        -1.3      0.288632
# 4         0.050000  0.200000  1.4     0.070000        -0.4      2.061660
#
#    Value_Score
# 0    -0.688163
# 1     0.000000
# 2    -0.953024
# 3    -4.353184
# 4    -0.193082
#
# [5 rows x 54 columns]

# %%
# Keep only strikers/forwards for main finishing analysis
attackers = df.copy()
# attackers = df[df['Pos'].str.contains('FW', na=False)].copy()
# Remove players with very few shots (set your own threshold)
# Example: Require at least 20 shots and 3 goals
attackers = attackers[
    (attackers['Shots'] >= 20) &
    (attackers['Goals'] >= 5) &
    (attackers['Playing Time_MP'] >= 12)  # or whatever your column is
]

# %%
# Calculate conversion rate and xG per shot
attackers['Shot_Conversion'] = attackers['Goals'] / attackers['Shots']
attackers['xG_per_shot'] = attackers['Expected_xG'] / attackers['Shots']
xg_mean = attackers['xG_per_shot'].mean()
conv_mean = attackers['Shot_Conversion'].mean()

# %% [markdown]
# Scoring goals wins matches—but not all goals are created equal. Some attackers shine by converting tough chances, while others get plenty of opportunities but struggle to finish. In this article, we use data visualization to see *how* Serie A's forwards are finishing their chances—not just how many times they find the net.
#
# We’ll use two powerful metrics:
# - **xG per shot:** How good are the chances each player gets?
# - **Shot conversion rate:** How often do those shots turn into goals?
#
# And then, we’ll go a step further, seeing who is outperforming or underperforming their expected goals (xG).

# %% [markdown]
# **xG per shot:**
# - Measures the average "quality" of each shot (higher means more big chances).
#
# **Shot conversion rate:**
# - Percent of shots that become goals.
#
# We look at all attackers with at least 20 shots in Serie A [2024–25] for a fair comparison.
# *Data via [FBref](https://fbref.com/), plots built in Python (see code below).*

# %% [markdown]
# ### How Serie A Attackers Finish Their Chances
#
# ![Insert: Quadrant Plot - All Names, Bubbles = Shots]
#
# - Each dot: a player (bubble size = shot volume)
# - Red/blue dashed lines: league averages for xG/shot and conversion rate
# - Quadrants: Clinical Finishers, Poachers, Underperformers, Volume Shooters
#
# *See the legend for bubble sizes. All attackers labeled. Key quadrant leaders boxed for clarity.*

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

plt.figure(figsize=(13, 9))

dot_size = 56

# Calculate means for quadrants
xbar = attackers['xG_per_shot'].mean()
ybar = attackers['Shot_Conversion'].mean()

# Scatter plot of all players
plt.scatter(
    attackers['xG_per_shot'],
    attackers['Shot_Conversion'],
    s=dot_size,
    c='skyblue',
    alpha=0.8,
    edgecolor='k'
)

# Draw quadrant lines
plt.axvline(xbar, color='red', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
plt.axhline(ybar, color='blue', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
plt.text(xbar+0.002, plt.ylim()[1]*0.99, "Avg xG/Shot", color='red', fontsize=10, ha='left', va='top')
plt.text(plt.xlim()[1]*0.99, ybar+0.002, "Avg Conv.", color='blue', fontsize=10, ha='right', va='bottom')

plt.xlabel('xG per Shot (Chance Quality)', fontsize=13)
plt.ylabel('Shot Conversion Rate (Goals/Shots)', fontsize=13)
plt.title('Serie A Attackers: Conversion Rate vs. Chance Quality (2024–25)', fontsize=16, fontweight='bold')
plt.suptitle('Each player labeled | Top 5 scorers in purple', fontsize=11, color='gray', y=0.93, style='italic')
plt.grid(alpha=0.22, linestyle=':', zorder=0)
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Legend for dashed lines
legend_elements = [
    Line2D([0], [0], color='red', lw=2, linestyle='--', label='Avg xG/Shot'),
    Line2D([0], [0], color='blue', lw=2, linestyle='--', label='Avg Shot Conversion')
]
plt.legend(handles=legend_elements, loc='lower right', fontsize=10, frameon=True, title="Dashed Lines", title_fontsize=11)

# --------- Highlight Top 5 Scorers ---------
top_n = 5
top_scorer_indices = set(attackers.nlargest(top_n, 'Goals').index)

for i, row in attackers.iterrows():
    if i in top_scorer_indices:
        plt.text(
            row['xG_per_shot'],
            row['Shot_Conversion'] + 0.003,
            row['Player'],
            fontsize=10,
            ha='center',
            va='bottom',
            color='purple',
            fontweight='bold',
            alpha=0.98,
            zorder=6
        )
    else:
        plt.text(
            row['xG_per_shot'],
            row['Shot_Conversion'] + 0.003,
            row['Player'],
            fontsize=8.6,
            ha='center',
            va='bottom',
            color='#24292f',
            alpha=0.96,
            zorder=4
        )

plt.savefig("seriea_quadrant_dots_top5scorers.png", dpi=220, bbox_inches='tight')
plt.show()

# %%
pip install adjustText
# Out:
# Collecting adjustText
#   Downloading adjustText-1.3.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from adjustText) (2.3.1)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from adjustText) (3.10.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from adjustText) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)
# Downloading adjustText-1.3.0-py3-none-any.whl (13 kB)
# Installing collected packages: adjustText
# Successfully installed adjustText-1.3.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

plt.rcParams['font.family'] = 'DejaVu Sans'

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

dot_size = 56

xbar = attackers['xG_per_shot'].mean()
ybar = attackers['Shot_Conversion'].mean()

# --- TOP 10 SCORERS ---
top_n = 10
top_scorers = attackers.nlargest(top_n, 'Goals').sort_values('Goals', ascending=False)
top_scorer_indices = set(top_scorers.index)

# --- SCATTERPLOT (ax1) with colorbar ---
sc = ax1.scatter(
    attackers['xG_per_shot'],
    attackers['Shot_Conversion'],
    s=dot_size,
    c=attackers['Goals'],
    cmap='viridis',
    alpha=0.88,
    edgecolor='k',
    zorder=3
)
cbar = plt.colorbar(sc, ax=ax1, orientation='vertical', pad=0.02)
cbar.set_label('Goals Scored', fontsize=11)

ax1.axvline(xbar, color='red', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
ax1.axhline(ybar, color='blue', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
ax1.text(xbar+0.002, ax1.get_ylim()[1]*0.99, "Avg xG/Shot", color='red', fontsize=10, ha='left', va='top')
ax1.text(ax1.get_xlim()[1]*0.99, ybar+0.002, "Avg Conv.", color='blue', fontsize=10, ha='right', va='bottom')

ax1.set_xlabel('xG per Shot (Chance Quality)', fontsize=13)
ax1.set_ylabel('Goals per Shot (Shot efficiency)', fontsize=13)
ax1.set_title('Serie A Attackers: Conversion Rate vs. Chance Quality (2024–25)', fontsize=16, fontweight='bold')
ax1.grid(alpha=0.17, linestyle=':', zorder=0, linewidth=0.9)

legend_elements = [
    Line2D([0], [0], color='red', lw=2, linestyle='--', label='Avg xG/Shot'),
    Line2D([0], [0], color='blue', lw=2, linestyle='--', label='Avg Shot Conversion')
]
ax1.legend(handles=legend_elements, loc='lower right', fontsize=10, frameon=True, title="Dashed Lines", title_fontsize=11)


# --- Label the quadrants ---
# Calculate the range for placement
x_min, x_max = ax1.get_xlim()
y_min, y_max = ax1.get_ylim()
x_center = xbar
y_center = ybar
dx = (x_max - x_min) * 0.05
dy = (y_max - y_min) * 0.04

ax1.text(x_min + dx, y_max - dy, 'Efficient Finisher', fontsize=12, color='darkgreen', weight='bold')
ax1.text(x_max - dx, y_max - dy, 'Elite Finisher', fontsize=12, color='darkblue', weight='bold', ha='right')


# Move bottom left label ("Inefficient Finisher") closer to center
ax1.text(
    x_min + (xbar - x_min) * 0.75,  # halfway between min and center
    y_min + (ybar - y_min) * 0.05,  # just above the x-axis
    'Inefficient Finisher',
    fontsize=12, color='gray', weight='bold', ha='center', va='bottom'
)

# Move bottom right label ("Chance Waster") closer to center
ax1.text(
    xbar + (x_max - xbar) * 0.35,   # halfway between center and max
    y_min + (ybar - y_min) * 0.05,
    'Chance Waster',
    fontsize=12, color='darkorange', weight='bold', ha='center', va='bottom'
)


# --- Quadrant outliers (highlighted/boxed) ---
highlight_indices = []
quad_colors = ['limegreen', 'royalblue', 'crimson', 'darkorange']

# Top left: Low xG/shot, high conversion (clinical finisher)
tl = attackers[(attackers['xG_per_shot'] < xbar) & (attackers['Shot_Conversion'] > ybar)]
if not tl.empty:
    idx_tl = tl['Shot_Conversion'].idxmax()
    highlight_indices.append(idx_tl)

# Top right: High xG/shot, high conversion (best chances, best finishers)
tr = attackers[(attackers['xG_per_shot'] > xbar) & (attackers['Shot_Conversion'] > ybar)]
if not tr.empty:
    idx_tr = tr['Shot_Conversion'].idxmax()
    highlight_indices.append(idx_tr)

# Bottom right: Highlight Dusan Vlahovic specifically
br = attackers[attackers['Player'].str.lower() == 'dusan vlahovic']
if not br.empty:
    idx_br = br.index[0]
    highlight_indices.append(idx_br)

already_boxed = set()
for idx, color in zip(highlight_indices, quad_colors):
    row = attackers.loc[idx]
    ax1.text(
        row['xG_per_shot'],
        row['Shot_Conversion'] + 0.003,
        row['Player'],
        fontsize=10,
        ha='center',
        va='bottom',
        color=color,
        fontweight='bold',
        bbox=dict(boxstyle="round,pad=0.22", edgecolor=color, facecolor='white', lw=2, alpha=0.99),
        zorder=8
    )
    already_boxed.add(idx)

# --- Annotate all names, highlight top scorers in purple unless boxed above ---
for i, row in attackers.iterrows():
    if i in already_boxed:
        continue  # already annotated as a boxed outlier
    color = 'purple' if i in top_scorer_indices else '#24292f'
    fontweight = 'bold' if i in top_scorer_indices else 'normal'
    fontsize = 10 if i in top_scorer_indices else 8.6
    ax1.text(
        row['xG_per_shot'],
        row['Shot_Conversion'] + 0.003,
        row['Player'],
        fontsize=fontsize,
        ha='center',
        va='bottom',
        color=color,
        fontweight=fontweight,
        alpha=0.98 if i in top_scorer_indices else 0.96,
        zorder=6 if i in top_scorer_indices else 4
    )

# --- BARPLOT (ax2) ---
# Color the top scorer gold, others blue
bar_colors = ['gold'] + ['mediumslateblue'] * (len(top_scorers) - 1)
ax2.barh(top_scorers['Player'], top_scorers['Goals'], color=bar_colors, alpha=0.92)
ax2.set_xlabel('Goals (2024–25)', fontsize=13)
ax2.set_ylabel('Top 10 Serie A Scorers', fontsize=14)
ax2.invert_yaxis()
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
for i, v in enumerate(top_scorers['Goals']):
    ax2.text(v + 0.5, i, str(int(v)), color='dimgray', va='center', fontsize=11, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.subplots_adjust(hspace=0.18)
plt.suptitle(
    'Serie A Attacker Analysis: Chance Quality, Conversion, and Top Scorers',
    fontsize=18, fontweight='bold', color='#263ca3', y=0.995
)

plt.savefig("seriea_quadrant_dots_top10scorers_upd.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
inefficient = attackers[
    (attackers['xG_per_shot'] < xbar) & (attackers['Shot_Conversion'] < ybar)
]

team_counts = inefficient['Squad'].value_counts().sort_values(ascending=False)

import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
bars = plt.barh(team_counts.index, team_counts.values, color='gray', alpha=0.85)
plt.xlabel('Number of Inefficient Finishers', fontsize=12)
plt.ylabel('Team', fontsize=12)
plt.title('Number of Inefficient Finishers (Lower Left Quadrant) by Team', fontsize=14, weight='bold')
plt.gca().invert_yaxis()
plt.grid(axis='x', linestyle=':', alpha=0.17)

# Optionally add value labels
for bar in bars:
    plt.text(bar.get_width() + 0.1, bar.get_y() + bar.get_height()/2, int(bar.get_width()),
             va='center', fontsize=11)

plt.tight_layout()
plt.show()

# %%
attackers.head()
# Out:
#      Rk                Player   Nation    Pos       Squad  Age  Born  \
# 1     8             che adams  sct SCO     FW      torino   28  1996
# 5    55         lucas beltran   ar ARG  FW,MF  fiorentina   23  2001
# 6    74       ange-yoan bonny   fr FRA     FW       parma   20  2003
# 9   114  valentin castellanos   ar ARG     FW       lazio   25  1998
# 10  115       santiago castro   ar ARG     FW     bologna   19  2004
#
#     Playing Time_MP  Playing Time_Starts  Playing Time_Min  ...  Shots  SoT  \
# 1                36                   30              2652  ...     63   25
# 5                32                   20              1864  ...     26    6
# 6                37                   30              2529  ...     61   19
# 9                29                   28              2384  ...    105   36
# 10               36                   27              2294  ...     62   20
#
#     Goals_per90  Shot_Conversion   SoT_pct    xG  xG_per_shot  G_minus_xG  \
# 1      0.305430         0.142857  0.396825   9.0     0.142857         0.0
# 5      0.241416         0.192308  0.230769   5.4     0.207692        -0.4
# 6      0.213523         0.098361  0.311475   9.4     0.154098        -3.4
# 9      0.377517         0.095238  0.342857  13.4     0.127619        -3.4
# 10     0.313862         0.129032  0.322581   7.7     0.124194         0.3
#
#     Salary_M_USD  Value_Score
# 1       3.432664     0.000000
# 5       2.381218    -0.167279
# 6       0.556648    -6.000198
# 9       2.381218    -1.421870
# 10      0.958672     0.309702
#
# [5 rows x 54 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

plt.rcParams['font.family'] = 'DejaVu Sans'

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 12), gridspec_kw={'height_ratios': [3, 1]})

dot_size = 56

xbar = attackers['xG_per_shot'].mean()
ybar = attackers['Shot_Conversion'].mean()

# --- TOP 10 SCORERS ---
top_n = 10
top_scorers = attackers.nlargest(top_n, 'Goals').sort_values('Goals', ascending=False)
top_scorer_indices = set(top_scorers.index)

# --- G–xG Color ---
attackers['G_minus_xG'] = attackers['Goals'] - attackers['xG']

# --- SCATTERPLOT (ax1) with G–xG colorbar ---
sc = ax1.scatter(
    attackers['xG_per_shot'],
    attackers['Shot_Conversion'],
    s=dot_size,
    c=attackers['G_minus_xG'],
    cmap='coolwarm',
    alpha=0.88,
    edgecolor='k',
    zorder=3
)
cbar = plt.colorbar(sc, ax=ax1, orientation='vertical', pad=0.02)
cbar.set_label('Goals Minus Expected Goals (G–xG)', fontsize=11)

ax1.axvline(xbar, color='red', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
ax1.axhline(ybar, color='blue', linestyle='--', linewidth=1.2, alpha=0.65, zorder=2)
ax1.text(xbar+0.002, ax1.get_ylim()[1]*0.99, "Avg xG/Shot", color='red', fontsize=10, ha='left', va='top')
ax1.text(ax1.get_xlim()[1]*0.99, ybar+0.002, "Avg Conv.", color='blue', fontsize=10, ha='right', va='bottom')

ax1.set_xlabel('xG per Shot (Chance Quality)', fontsize=13)
ax1.set_ylabel('Goals per Shot (Shot efficiency)', fontsize=13)
ax1.set_title('Serie A Attackers: Conversion Rate vs. Chance Quality (2024–25)', fontsize=16, fontweight='bold')
ax1.grid(alpha=0.17, linestyle=':', zorder=0, linewidth=0.9)

legend_elements = [
    Line2D([0], [0], color='red', lw=2, linestyle='--', label='Avg xG/Shot'),
    Line2D([0], [0], color='blue', lw=2, linestyle='--', label='Avg Shot Conversion')
]
ax1.legend(handles=legend_elements, loc='lower right', fontsize=10, frameon=True, title="Dashed Lines", title_fontsize=11)

# --- Quadrant Labels ---
x_min, x_max = ax1.get_xlim()
y_min, y_max = ax1.get_ylim()
x_center = xbar
y_center = ybar
dx = (x_max - x_min) * 0.05
dy = (y_max - y_min) * 0.04

ax1.text(x_min + dx, y_max - dy, 'Efficient Finisher', fontsize=12, color='darkgreen', weight='bold')
ax1.text(x_max - dx, y_max - dy, 'Elite Finisher', fontsize=12, color='darkblue', weight='bold', ha='right')

ax1.text(
    x_min + (xbar - x_min) * 0.75,
    y_min + (ybar - y_min) * 0.05,
    'Inefficient Finisher',
    fontsize=12, color='gray', weight='bold', ha='center', va='bottom'
)
ax1.text(
    xbar + (x_max - xbar) * 0.35,
    y_min + (ybar - y_min) * 0.05,
    'Chance Waster',
    fontsize=12, color='darkorange', weight='bold', ha='center', va='bottom'
)

# --- Quadrant outliers (highlighted/boxed) ---
highlight_indices = []
quad_colors = ['limegreen', 'royalblue', 'crimson', 'darkorange']

# Top left: Low xG/shot, high conversion (clinical finisher)
tl = attackers[(attackers['xG_per_shot'] < xbar) & (attackers['Shot_Conversion'] > ybar)]
if not tl.empty:
    idx_tl = tl['Shot_Conversion'].idxmax()
    highlight_indices.append(idx_tl)

# Top right: High xG/shot, high conversion (best chances, best finishers)
tr = attackers[(attackers['xG_per_shot'] > xbar) & (attackers['Shot_Conversion'] > ybar)]
if not tr.empty:
    idx_tr = tr['Shot_Conversion'].idxmax()
    highlight_indices.append(idx_tr)

# Bottom right: Highlight Dusan Vlahovic specifically
br = attackers[attackers['Player'].str.lower() == 'dusan vlahovic']
if not br.empty:
    idx_br = br.index[0]
    highlight_indices.append(idx_br)

already_boxed = set()
for idx, color in zip(highlight_indices, quad_colors):
    row = attackers.loc[idx]
    ax1.text(
        row['xG_per_shot'],
        row['Shot_Conversion'] + 0.003,
        row['Player'],
        fontsize=10,
        ha='center',
        va='bottom',
        color=color,
        fontweight='bold',
        bbox=dict(boxstyle="round,pad=0.22", edgecolor=color, facecolor='white', lw=2, alpha=0.99),
        zorder=8
    )
    already_boxed.add(idx)

# --- Annotate all names, highlight top scorers in purple unless boxed above ---
for i, row in attackers.iterrows():
    if i in already_boxed:
        continue  # already annotated as a boxed outlier
    color = 'purple' if i in top_scorer_indices else '#24292f'
    fontweight = 'bold' if i in top_scorer_indices else 'normal'
    fontsize = 10 if i in top_scorer_indices else 8.6
    ax1.text(
        row['xG_per_shot'],
        row['Shot_Conversion'] + 0.003,
        row['Player'],
        fontsize=fontsize,
        ha='center',
        va='bottom',
        color=color,
        fontweight=fontweight,
        alpha=0.98 if i in top_scorer_indices else 0.96,
        zorder=6 if i in top_scorer_indices else 4
    )

# --- BARPLOT (ax2) ---
bar_colors = ['gold'] + ['mediumslateblue'] * (len(top_scorers) - 1)
ax2.barh(top_scorers['Player'], top_scorers['Goals'], color=bar_colors, alpha=0.92)
ax2.set_xlabel('Goals (2024–25)', fontsize=13)
ax2.set_ylabel('Top 10 Serie A Scorers', fontsize=14)
ax2.invert_yaxis()
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
for i, v in enumerate(top_scorers['Goals']):
    ax2.text(v + 0.5, i, str(int(v)), color='dimgray', va='center', fontsize=11, fontweight='bold')

plt.tight_layout(rect=[0, 0, 1, 0.97])
plt.subplots_adjust(hspace=0.18)
plt.suptitle(
    'Serie A Attacker Analysis: Chance Quality, Conversion, and Top Scorers',
    fontsize=18, fontweight='bold', color='#263ca3', y=0.995
)

plt.savefig("seriea_quadrant_dots_top10scorers_g_xg_color.png", dpi=300, bbox_inches='tight')
plt.show()
